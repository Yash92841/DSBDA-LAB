# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash92841/DSBDA-LAB/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/data.csv')
df
# Out:
#     Age  Monthly Income  Attrition     BusinessTravel
# 0    42           44290          0  Travel_Frequently
# 1    24           43694          1      Travel_Rarely
# 2    40           23381          0         Non_Travel
# 3    29           47776          1         Non_Travel
# 4    44           41084          0  Travel_Frequently
# 5    41           43402          0         Non_Travel
# 6    22           31457          1         Non_Travel
# 7    28           30599          1  Travel_Frequently
# 8    37           56540          1         Non_Travel
# 9    32           33412          1      Travel_Rarely
# 10   26           38719          1      Travel_Rarely
# 11   37           23225          0      Travel_Rarely
# 12   26           31590          1         Non_Travel
# 13   26           51566          0      Travel_Rarely
# 14   45           33779          1         Non_Travel
# 15   22           53757          1         Non_Travel
# ...

# %%
print("the mean of monthlyincome :",df.loc[:,"Monthly Income"].mean())
print("the mean of age :",df.loc[:,"Age"].mean())
# Out:
# the mean of monthlyincome : 39891.1
# the mean of age : 31.35

# %%
print("The median of monthly income is :",df.loc[:,"Monthly Income"].median())
print("The median of age is :",df.loc[:,"Age"].median())
# Out:
# The median of monthly income is : 40519.5
# The median of age is : 28.5

# %%
print("The mode of monthly income is :",df.loc[:,"Monthly Income"].mode())
print("The mode of age is :",df.loc[:,"Age"].mode())
# Out:
# The mode of monthly income is : 0     23225
# 1     23381
# 2     29375
# 3     30599
# 4     31457
# 5     31590
# 6     33412
# 7     33779
# 8     38719
# 9     39955
# 10    41084
# 11    43402
# 12    43694
# 13    44290
# 14    47706
# 15    47776
# 16    51566
# 17    52515
# 18    53757
# 19    56540
# Name: Monthly Income, dtype: int64
# The mode of age is : 0    26
# Name: Age, dtype: int64

# %%
print("The standard deviation of monthly income is :",df.loc[:,"Monthly Income"].std())
print("The standard deviation of age is :",df.loc[:,"Age"].std())
# Out:
# The standard deviation of monthly income is : 10010.39403451811
# The standard deviation of age is : 7.768187487574258

# %%
arr1=np.array(df['Monthly Income'])
arr2=np.array(df['Age'])
print("Income",arr1)
print("Age array",arr2)
# Out:
# Income [44290 43694 23381 47776 41084 43402 31457 30599 56540 33412 38719 23225
#  31590 51566 33779 53757 47706 52515 39955 29375]
# Age array [42 24 40 29 44 41 22 28 37 32 26 37 26 26 45 22 24 25 26 31]

# %%
print("Maximum income among the employees :",max(arr1))
print("Minimum income among the employees  :",min(arr1))
print("Maximum age among the employees :",max(arr2))
print("Minimum age among the employees :",min(arr2))
# Out:
# Maximum income among the employees : 56540
# Minimum income among the employees  : 23225
# Maximum age among the employees : 45
# Minimum age among the employees : 22

# %%
df.head()
df["BusinessTravel"].replace({"Travel_Rarely":1, "Travel_Frequently":0, "Non_Travel":np.NaN}, inplace=True)
df["Attrition"].replace({ 1:"Yes", 0:"No"}, inplace=True)
df['BusinessTravel'] =df["BusinessTravel"].astype("Int64")
df.head()
# Out:
# <ipython-input-19-f271a295da56>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["BusinessTravel"].replace({"Travel_Rarely":1, "Travel_Frequently":0, "Non_Travel":np.NaN}, inplace=True)
# <ipython-input-19-f271a295da56>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a8ac5847051b> in <cell line: 0>()
# ----> 1 plt.hist(mean, bin=5,color='skyblue',edgecolor='black')
#       2 plt.title('Histogram Example')
#       3 plt.xlabel('Value')
#       4 plt.ylabel('Frequency')
#       5
#
# NameError: name 'mean' is not defined

# %%
meanage=df['Age'].mean()
medianage=df['Age'].median()
stdage=df['Age'].std()
modeage=df['Age'].mode()
medianage
# Out:
# 28.5

# %%
plt.hist(meanage, bins=32, alpha=1, label='Dataset 1', color='blue')
plt.hist(medianage , bins=29, alpha=1, label='Dataset 2', color='red')
plt.hist(stdage, bins=8,alpha=1, label='Dataset 3', color='black')

plt.legend()
plt.show()
